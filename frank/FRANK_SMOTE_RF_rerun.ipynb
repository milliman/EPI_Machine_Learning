# %%
import scipy as sp
from sklearn.svm import SVC
import pandas as pd
import numpy as np
from scipy.stats import randint as sp_randint
from sklearn import svm
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import brier_score_loss
from sklearn.model_selection import RandomizedSearchCV
from time import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
#NEED INSTALL IMBLANCE PACKAGE
#code: conda install -c glemaitre imbalanced-learn
from imblearn.over_sampling import SMOTE
#read tables: After variable selection, choosing 50 variables by baseline RF importance
train=pd.read_table('training_self1_0127.txt')
test=pd.read_table('testing_self1_0127.txt')

# %%
train_Ycat=train['Ycat']
train_PERT=train['PERT_Y']
train=train.drop('Ycat',1)
train=train.drop('MemberID',1)
train=train.drop('PERT_Y',1)

test_Ycat=test['Ycat']
test_PERT=test['PERT_Y']
test=test.drop('Ycat',1)
test=test.drop('PERT_Y',1)
test=test.drop('MemberID',1)

scaler = MinMaxScaler()
train = scaler.fit_transform(train)
test =  scaler.transform(test)

train_std=pd.DataFrame(train)
test_std=pd.DataFrame(test)

res=[1 if x =='Y' else 0 for x in train_PERT]

# %%
sm = SMOTE(random_state=1234,ratio=.2)
X_res, y_res = sm.fit_sample(train_std, res)

# %%
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
#hyper parameter options, could also apply to other model. 
param_dist = {"max_depth": [3, None],
              "max_features": sp_randint(1, 20),
              "min_samples_split": sp_randint(2, 11),
              "min_samples_leaf": sp_randint(1, 11),
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

# %% [markdown]
# # Optimize Hyper-parameters by F1 Score

# %%
#model1
rf=RandomForestClassifier(n_estimators=100)

# %%
#search 50 times
seed = np.random.seed(1234)
n_iter_search = 20
random_search = RandomizedSearchCV(rf, param_distributions=param_dist,
                                   n_iter=n_iter_search,scoring ='f1',  n_jobs=-1, verbose=100,
                                   pre_dispatch =10)

start = time()
random_search.fit(X_res,y_res )
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time() - start), n_iter_search))

report(random_search.cv_results_)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Memmaping (shape=(421062L, 51L), dtype=float64) to new file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to new file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to new file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to new file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to new file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to new file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to new file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to new file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  1.8min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:  1.9min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:  3.8min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  3.9min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  4.7min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  5.1min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  5.1min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  5.4min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  5.8min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  6.3min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  7.0min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  8.0min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  8.4min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  8.5min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed: 10.9min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed: 12.2min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed: 12.7min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed: 12.8min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed: 13.7min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed: 13.9min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed: 14.3min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed: 14.5min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed: 14.7min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 14.9min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed: 15.7min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed: 16.0min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed: 16.1min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed: 16.2min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed: 16.3min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed: 16.6min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed: 16.7min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 16.7min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 18.3min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed: 18.4min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed: 19.2min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 19.4min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed: 19.8min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed: 19.9min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed: 20.0min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed: 20.7min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 21.3min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed: 23.7min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed: 24.1min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed: 24.9min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 25.1min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed: 25.1min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed: 25.2min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280707L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-5ff6027c1f0dfb71e9be14d66cfa5499.pkl
# Memmaping (shape=(140355L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-a5091e1951d332bf63830e38c9eb6ee5.pkl
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed: 25.4min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280708L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-4434036b60e92d2270fb927019e3e63a.pkl
# Memmaping (shape=(140354L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-86d33daf69599535f8a1eb81d2c7e44b.pkl
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 26.1min
# Memmaping (shape=(421062L, 51L), dtype=float64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-9005ccc209ccf046c5d5153ae592621a.pkl
# Memmaping (shape=(421062L,), dtype=int32) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-83f7956e1aa6563de788f77dc68fb8e9.pkl
# Memmaping (shape=(280709L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-50af1a1cef47b7697387d1790d67b3d9.pkl
# Memmaping (shape=(140353L,), dtype=int64) to old file c:\users\motoharu.dei\appdata\local\temp\joblib_memmaping_pool_6232_156298320\6232-278938624-247d31aca8fb3569fafd928c0b78705e.pkl
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed: 26.4min
# [Parallel(n_jobs=-1)]: Done  52 out of  60 | elapsed: 26.4min remaining:  4.1min
# [Parallel(n_jobs=-1)]: Done  53 out of  60 | elapsed: 26.5min remaining:  3.5min
# [Parallel(n_jobs=-1)]: Done  54 out of  60 | elapsed: 26.7min remaining:  3.0min
# [Parallel(n_jobs=-1)]: Done  55 out of  60 | elapsed: 27.5min remaining:  2.5min
# [Parallel(n_jobs=-1)]: Done  56 out of  60 | elapsed: 27.7min remaining:  2.0min
# [Parallel(n_jobs=-1)]: Done  57 out of  60 | elapsed: 27.7min remaining:  1.5min
# [Parallel(n_jobs=-1)]: Done  58 out of  60 | elapsed: 28.1min remaining:   58.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed: 30.2min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed: 30.2min finished
# RandomizedSearchCV took 2032.78 seconds for 20 candidates parameter settings.
# Model with rank: 1
# Mean validation score: 0.988 (std: 0.009)
# Parameters: {'bootstrap': False, 'min_samples_leaf': 1, 'min_samples_split': 4, 'criterion': 'gini', 'max_features': 10, 'max_depth': None}
#
# Model with rank: 2
# Mean validation score: 0.988 (std: 0.011)
# Parameters: {'bootstrap': False, 'min_samples_leaf': 1, 'min_samples_split': 10, 'criterion': 'entropy', 'max_features': 14, 'max_depth': None}
#
# Model with rank: 3
# Mean validation score: 0.987 (std: 0.009)
# Parameters: {'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 5, 'criterion': 'gini', 'max_features': 13, 'max_depth': None}

# %%
#RandomizedSearchCV took 2039.49 seconds for 20 candidates parameter settings.
#Model with rank: 1
#Mean validation score: 0.988 (std: 0.009)
#Parameters: {'bootstrap': False, 'min_samples_leaf': 1, 'min_samples_split': 4, 
#'criterion': 'gini', 'max_features': 10, 'max_depth': None}

rf=RandomForestClassifier(n_estimators=500)
rf=RandomForestClassifier(criterion='gini', max_depth=None, min_samples_split=4, 
                       min_samples_leaf=1,max_features=10,bootstrap=False,random_state=1234)

# %%
#fit the model
rf.fit(X_res,y_res)

predicted_probs = rf.predict_proba(train_std)
a= predicted_probs[:,1]
np.mean(a)
b= predicted_probs[:,0]
np.mean(b)
a1=sorted(a,reverse=True)
a2=pd.DataFrame(a1)
a2.iloc[train_PERT.value_counts()["Y"]*4-1,:]
# Out:
# 0    0.033333
# Name: 6679, dtype: float64

# %%
#Synchronize with Jeff's Scoring Functions
from sklearn.metrics import accuracy_score, precision_score, recall_score, \
    f1_score, roc_auc_score, average_precision_score, brier_score_loss, \
    fbeta_score, confusion_matrix
from creonmetrics import labeled_metric, assumed_metric, pu_score, \
    pr_one_unlabeled, brier_score_partial_loss

y_true = test_Ycat.values
y_prob = rf.predict_proba(test_std)

y_pred=np.array([1 if x >= 0.033333 else 0 for x in y_prob[:,1]])

# %%
import collections
data = {'labeled_acc' : labeled_metric(y_true, y_pred, accuracy_score),
        'labeled_prec' : labeled_metric(y_true, y_pred, precision_score),
        'labeled_recall' : labeled_metric(y_true, y_pred, recall_score),
        'labeled_f1' : labeled_metric(y_true, y_pred, f1_score),
        'labeled_roc_auc' : labeled_metric(y_true, y_pred, roc_auc_score),
        'labeled_avg_prec' : labeled_metric(y_true, y_pred, average_precision_score),
        'labeled_brier' : labeled_metric(y_true, y_prob, brier_score_loss),
        'labeled_brier_pos' : labeled_metric(y_true, y_prob, brier_score_partial_loss, label=1),
        'labeled_brier_neg' : labeled_metric(y_true, y_prob, brier_score_partial_loss, label=0),
        'confusion_matrix_lab' : labeled_metric(y_true, y_pred, confusion_matrix),
        'pr_one_unlabeled' : pr_one_unlabeled(y_true, y_pred),
        'assumed_brier' : assumed_metric(y_true, y_prob, brier_score_loss),
        'assumed_brier_neg' : assumed_metric(y_true, y_prob, brier_score_partial_loss, label=0),
        'assumed_f1' : assumed_metric(y_true, y_pred, f1_score),
        'assumed_f1beta10' : assumed_metric(y_true, y_pred, fbeta_score, beta=10),
        'confusion_matrix_un' : assumed_metric(y_true, y_pred, confusion_matrix),
        'pu_score' : pu_score(y_true, y_pred),
        }
data_s = collections.OrderedDict(sorted(data.items()))
for k, v in data_s.items():
    print(k, ': ', v)
# Out:
# assumed_brier :  0.00562505987948
# assumed_brier_neg :  0.00238222896068
# assumed_f1 :  0.0962722852512
# assumed_f1beta10 :  0.630825201884
# confusion_matrix_lab :  [[160  56]
#  [121 297]]
# confusion_matrix_un :  [[82267  5455]
#  [  121   297]]
# labeled_acc :  0.720820189274
# labeled_avg_prec :  0.871368912088
# labeled_brier :  0.457327812829
# labeled_brier_neg :  0.0144765946502
# labeled_brier_pos :  0.686169590643
# labeled_f1 :  0.770428015564
# labeled_prec :  0.841359773371
# labeled_recall :  0.710526315789
# labeled_roc_auc :  0.725633528265
# pr_one_unlabeled :  0.0616986263799
# pu_score :  7.73596513702

# %% [markdown]
# # Optimize Hyper-parameters by Recall*Precision

# %%
from sklearn.metrics import precision_recall_fscore_support,recall_score, make_scorer,precision_score

def pu(actual,prediction):
    precision = precision_score(actual, prediction)
    recall = recall_score(actual, prediction)
    pu= precision*recall
    return pu

pu_score=make_scorer(pu,greater_is_better=True)

# %%
rf=RandomForestClassifier(n_estimators=100)

# %%
#search 50 times     
seed = np.random.seed(1234)
n_iter_search = 20
random_search = RandomizedSearchCV(rf, param_distributions=param_dist,
                                   n_iter=n_iter_search,scoring =pu_score, verbose=100,
                                  )

start = time()
random_search.fit(X_res,y_res )
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time() - start), n_iter_search))

report(random_search.cv_results_)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] max_features=13, max_depth=3, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=10
# [CV]  max_features=13, max_depth=3, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=10, score=0.682543, total=  44.6s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   46.4s remaining:    0.0s
# [CV] max_features=13, max_depth=3, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=10
# [CV]  max_features=13, max_depth=3, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=10, score=0.726020, total=  43.6s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.5min remaining:    0.0s
# [CV] max_features=13, max_depth=3, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=10
# [CV]  max_features=13, max_depth=3, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=10, score=0.714902, total=  43.7s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  2.3min remaining:    0.0s
# [CV] max_features=17, max_depth=3, min_samples_leaf=6, criterion=entropy, bootstrap=False, min_samples_split=4
# [CV]  max_features=17, max_depth=3, min_samples_leaf=6, criterion=entropy, bootstrap=False, min_samples_split=4, score=0.723364, total=  56.3s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  3.3min remaining:    0.0s
# [CV] max_features=17, max_depth=3, min_samples_leaf=6, criterion=entropy, bootstrap=False, min_samples_split=4
# [CV]  max_features=17, max_depth=3, min_samples_leaf=6, criterion=entropy, bootstrap=False, min_samples_split=4, score=0.762029, total=  55.3s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  4.2min remaining:    0.0s
# [CV] max_features=17, max_depth=3, min_samples_leaf=6, criterion=entropy, bootstrap=False, min_samples_split=4
# [CV]  max_features=17, max_depth=3, min_samples_leaf=6, criterion=entropy, bootstrap=False, min_samples_split=4, score=0.754040, total=  55.7s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  5.2min remaining:    0.0s
# [CV] max_features=2, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=3
# [CV]  max_features=2, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=3, score=0.151327, total=   9.6s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  5.4min remaining:    0.0s
# [CV] max_features=2, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=3
# [CV]  max_features=2, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=3, score=0.144891, total=   9.5s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  5.6min remaining:    0.0s
# [CV] max_features=2, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=3
# [CV]  max_features=2, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=3, score=0.044589, total=   9.6s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  5.8min remaining:    0.0s
# [CV] max_features=19, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=False, min_samples_split=5
# [CV]  max_features=19, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=False, min_samples_split=5, score=0.944162, total= 3.4min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  9.2min remaining:    0.0s
# [CV] max_features=19, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=False, min_samples_split=5
# [CV]  max_features=19, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=False, min_samples_split=5, score=0.986720, total= 3.8min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 13.0min remaining:    0.0s
# [CV] max_features=19, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=False, min_samples_split=5
# [CV]  max_features=19, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=False, min_samples_split=5, score=0.985082, total= 3.8min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 16.9min remaining:    0.0s
# [CV] max_features=16, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=6
# [CV]  max_features=16, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=6, score=0.724579, total=  33.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 17.4min remaining:    0.0s
# [CV] max_features=16, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=6
# [CV]  max_features=16, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=6, score=0.741042, total=  32.5s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 18.0min remaining:    0.0s
# [CV] max_features=16, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=6
# [CV]  max_features=16, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=6, score=0.756791, total=  32.6s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 18.6min remaining:    0.0s
# [CV] max_features=5, max_depth=None, min_samples_leaf=4, criterion=gini, bootstrap=True, min_samples_split=4
# [CV]  max_features=5, max_depth=None, min_samples_leaf=4, criterion=gini, bootstrap=True, min_samples_split=4, score=0.946235, total=  45.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 19.4min remaining:    0.0s
# [CV] max_features=5, max_depth=None, min_samples_leaf=4, criterion=gini, bootstrap=True, min_samples_split=4
# [CV]  max_features=5, max_depth=None, min_samples_leaf=4, criterion=gini, bootstrap=True, min_samples_split=4, score=0.982287, total=  48.3s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 20.3min remaining:    0.0s
# [CV] max_features=5, max_depth=None, min_samples_leaf=4, criterion=gini, bootstrap=True, min_samples_split=4
# [CV]  max_features=5, max_depth=None, min_samples_leaf=4, criterion=gini, bootstrap=True, min_samples_split=4, score=0.981452, total=  48.3s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 21.1min remaining:    0.0s
# [CV] max_features=7, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=7
# [CV]  max_features=7, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=7, score=0.523591, total=  22.7s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 21.5min remaining:    0.0s
# [CV] max_features=7, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=7
# [CV]  max_features=7, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=7, score=0.554673, total=  22.5s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 21.9min remaining:    0.0s
# [CV] max_features=7, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=7
# [CV]  max_features=7, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=7, score=0.544753, total=  22.7s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed: 22.4min remaining:    0.0s
# [CV] max_features=10, max_depth=None, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=8
# [CV]  max_features=10, max_depth=None, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=8, score=0.947460, total= 2.0min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 24.4min remaining:    0.0s
# [CV] max_features=10, max_depth=None, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=8
# [CV]  max_features=10, max_depth=None, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=8, score=0.988352, total= 2.2min
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed: 26.7min remaining:    0.0s
# [CV] max_features=10, max_depth=None, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=8
# [CV]  max_features=10, max_depth=None, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=8, score=0.988016, total= 2.2min
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed: 28.9min remaining:    0.0s
# [CV] max_features=5, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=8
# [CV]  max_features=5, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=8, score=0.447981, total=  19.5s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 29.3min remaining:    0.0s
# [CV] max_features=5, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=8
# [CV]  max_features=5, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=8, score=0.519973, total=  19.4s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed: 29.6min remaining:    0.0s
# [CV] max_features=5, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=8
# [CV]  max_features=5, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=8, score=0.410137, total=  19.5s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 30.0min remaining:    0.0s
# [CV] max_features=8, max_depth=None, min_samples_leaf=5, criterion=gini, bootstrap=False, min_samples_split=10
# [CV]  max_features=8, max_depth=None, min_samples_leaf=5, criterion=gini, bootstrap=False, min_samples_split=10, score=0.947319, total= 1.5min
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed: 31.6min remaining:    0.0s
# [CV] max_features=8, max_depth=None, min_samples_leaf=5, criterion=gini, bootstrap=False, min_samples_split=10
# [CV]  max_features=8, max_depth=None, min_samples_leaf=5, criterion=gini, bootstrap=False, min_samples_split=10, score=0.984441, total= 1.8min
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed: 33.4min remaining:    0.0s
# [CV] max_features=8, max_depth=None, min_samples_leaf=5, criterion=gini, bootstrap=False, min_samples_split=10
# [CV]  max_features=8, max_depth=None, min_samples_leaf=5, criterion=gini, bootstrap=False, min_samples_split=10, score=0.984247, total= 1.8min
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 35.3min remaining:    0.0s
# [CV] max_features=14, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=4
# [CV]  max_features=14, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=4, score=0.671637, total=  34.0s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed: 35.8min remaining:    0.0s
# [CV] max_features=14, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=4
# [CV]  max_features=14, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=4, score=0.738020, total=  33.5s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed: 36.4min remaining:    0.0s
# [CV] max_features=14, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=4
# [CV]  max_features=14, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=4, score=0.724967, total=  33.7s
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed: 37.0min remaining:    0.0s
# [CV] max_features=19, max_depth=3, min_samples_leaf=1, criterion=gini, bootstrap=True, min_samples_split=2
# [CV]  max_features=19, max_depth=3, min_samples_leaf=1, criterion=gini, bootstrap=True, min_samples_split=2, score=0.747272, total=  38.7s
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed: 37.7min remaining:    0.0s
# [CV] max_features=19, max_depth=3, min_samples_leaf=1, criterion=gini, bootstrap=True, min_samples_split=2
# [CV]  max_features=19, max_depth=3, min_samples_leaf=1, criterion=gini, bootstrap=True, min_samples_split=2, score=0.756494, total=  38.2s
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed: 38.4min remaining:    0.0s
# [CV] max_features=19, max_depth=3, min_samples_leaf=1, criterion=gini, bootstrap=True, min_samples_split=2
# [CV]  max_features=19, max_depth=3, min_samples_leaf=1, criterion=gini, bootstrap=True, min_samples_split=2, score=0.736123, total=  38.0s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed: 39.0min remaining:    0.0s
# [CV] max_features=14, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=True, min_samples_split=9
# [CV]  max_features=14, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=True, min_samples_split=9, score=0.941236, total= 1.8min
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed: 40.8min remaining:    0.0s
# [CV] max_features=14, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=True, min_samples_split=9
# [CV]  max_features=14, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=True, min_samples_split=9, score=0.977838, total= 1.9min
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed: 42.8min remaining:    0.0s
# [CV] max_features=14, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=True, min_samples_split=9
# [CV]  max_features=14, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=True, min_samples_split=9, score=0.975973, total= 1.9min
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed: 44.8min remaining:    0.0s
# [CV] max_features=14, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=2
# [CV]  max_features=14, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=2, score=0.947475, total= 2.7min
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 47.5min remaining:    0.0s
# [CV] max_features=14, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=2
# [CV]  max_features=14, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=2, score=0.991721, total= 3.0min
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed: 50.6min remaining:    0.0s
# [CV] max_features=14, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=2
# [CV]  max_features=14, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=2, score=0.991304, total= 3.0min
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed: 53.6min remaining:    0.0s
# [CV] max_features=15, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=7
# [CV]  max_features=15, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=7, score=0.717120, total=  31.3s
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed: 54.2min remaining:    0.0s
# [CV] max_features=15, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=7
# [CV]  max_features=15, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=7, score=0.721936, total=  31.1s
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed: 54.7min remaining:    0.0s
# [CV] max_features=15, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=7
# [CV]  max_features=15, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=7, score=0.725875, total=  31.8s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 55.3min remaining:    0.0s
# [CV] max_features=12, max_depth=None, min_samples_leaf=2, criterion=entropy, bootstrap=False, min_samples_split=10
# [CV]  max_features=12, max_depth=None, min_samples_leaf=2, criterion=entropy, bootstrap=False, min_samples_split=10, score=0.946756, total= 2.3min
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed: 57.7min remaining:    0.0s
# [CV] max_features=12, max_depth=None, min_samples_leaf=2, criterion=entropy, bootstrap=False, min_samples_split=10
# [CV]  max_features=12, max_depth=None, min_samples_leaf=2, criterion=entropy, bootstrap=False, min_samples_split=10, score=0.990286, total= 2.6min
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed: 60.3min remaining:    0.0s
# [CV] max_features=12, max_depth=None, min_samples_leaf=2, criterion=entropy, bootstrap=False, min_samples_split=10
# [CV]  max_features=12, max_depth=None, min_samples_leaf=2, criterion=entropy, bootstrap=False, min_samples_split=10, score=0.990670, total= 2.6min
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed: 62.9min remaining:    0.0s
# [CV] max_features=18, max_depth=3, min_samples_leaf=2, criterion=gini, bootstrap=True, min_samples_split=2
# [CV]  max_features=18, max_depth=3, min_samples_leaf=2, criterion=gini, bootstrap=True, min_samples_split=2, score=0.758231, total=  36.5s
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed: 63.6min remaining:    0.0s
# [CV] max_features=18, max_depth=3, min_samples_leaf=2, criterion=gini, bootstrap=True, min_samples_split=2
# [CV]  max_features=18, max_depth=3, min_samples_leaf=2, criterion=gini, bootstrap=True, min_samples_split=2, score=0.764613, total=  36.1s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed: 64.2min remaining:    0.0s
# [CV] max_features=18, max_depth=3, min_samples_leaf=2, criterion=gini, bootstrap=True, min_samples_split=2
# [CV]  max_features=18, max_depth=3, min_samples_leaf=2, criterion=gini, bootstrap=True, min_samples_split=2, score=0.725597, total=  35.9s
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed: 64.9min remaining:    0.0s
# [CV] max_features=13, max_depth=3, min_samples_leaf=8, criterion=gini, bootstrap=False, min_samples_split=9
# [CV]  max_features=13, max_depth=3, min_samples_leaf=8, criterion=gini, bootstrap=False, min_samples_split=9, score=0.663888, total=  37.7s
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed: 65.5min remaining:    0.0s
# [CV] max_features=13, max_depth=3, min_samples_leaf=8, criterion=gini, bootstrap=False, min_samples_split=9
# [CV]  max_features=13, max_depth=3, min_samples_leaf=8, criterion=gini, bootstrap=False, min_samples_split=9, score=0.687244, total=  37.8s
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed: 66.2min remaining:    0.0s
# [CV] max_features=13, max_depth=3, min_samples_leaf=8, criterion=gini, bootstrap=False, min_samples_split=9
# [CV]  max_features=13, max_depth=3, min_samples_leaf=8, criterion=gini, bootstrap=False, min_samples_split=9, score=0.699927, total=  38.0s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed: 66.8min remaining:    0.0s
# [CV] max_features=6, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=False, min_samples_split=2
# [CV]  max_features=6, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=False, min_samples_split=2, score=0.461997, total=  20.2s
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed: 67.2min remaining:    0.0s
# [CV] max_features=6, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=False, min_samples_split=2
# [CV]  max_features=6, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=False, min_samples_split=2, score=0.533090, total=  20.0s
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed: 67.6min remaining:    0.0s
# [CV] max_features=6, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=False, min_samples_split=2
# [CV]  max_features=6, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=False, min_samples_split=2, score=0.519102, total=  20.3s
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed: 67.9min remaining:    0.0s
# [CV] max_features=7, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=3
# [CV]  max_features=7, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=3, score=0.950495, total= 1.1min
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed: 69.1min remaining:    0.0s
# [CV] max_features=7, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=3
# [CV]  max_features=7, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=3, score=0.987472, total= 1.1min
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed: 70.3min remaining:    0.0s
# [CV] max_features=7, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=3
# [CV]  max_features=7, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=3, score=0.987310, total= 1.2min
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed: 71.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed: 71.5min finished
# RandomizedSearchCV took 4576.51 seconds for 20 candidates parameter settings.
# Model with rank: 1
# Mean validation score: 0.977 (std: 0.021)
# Parameters: {'max_features': 14, 'max_depth': None, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': False, 'min_samples_split': 2}
#
# Model with rank: 2
# Mean validation score: 0.976 (std: 0.021)
# Parameters: {'max_features': 12, 'max_depth': None, 'min_samples_leaf': 2, 'criterion': 'entropy', 'bootstrap': False, 'min_samples_split': 10}
#
# Model with rank: 3
# Mean validation score: 0.975 (std: 0.017)
# Parameters: {'max_features': 7, 'max_depth': None, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': True, 'min_samples_split': 3}

# %%
#RandomizedSearchCV took 4576.51 seconds for 20 candidates parameter settings.
#Model with rank: 1
#Mean validation score: 0.977 (std: 0.021)
#Parameters: {'max_features': 14, 'max_depth': None, 'min_samples_leaf': 1, 'criterion': 'entropy', 
#'bootstrap': False, 'min_samples_split': 2}

rf=RandomForestClassifier(n_estimators=500)
rf=RandomForestClassifier(criterion='entropy', max_depth=None, min_samples_split=2, 
                       min_samples_leaf=1,max_features=14,bootstrap=False,random_state=1234)

# %%
#fit the model
rf.fit(X_res,y_res)

predicted_probs = rf.predict_proba(train_std)
a= predicted_probs[:,1]
np.mean(a)
b= predicted_probs[:,0]
np.mean(b)
a1=sorted(a,reverse=True)
a2=pd.DataFrame(a1)
a2.iloc[train_PERT.value_counts()["Y"]*4-1,:]
# Out:
# 0    0.0
# Name: 6679, dtype: float64

# %%
#Synchronize with Jeff's Scoring Functions
from sklearn.metrics import accuracy_score, precision_score, recall_score, \
    f1_score, roc_auc_score, average_precision_score, brier_score_loss, \
    fbeta_score, confusion_matrix
from creonmetrics import labeled_metric, assumed_metric, pu_score, \
    pr_one_unlabeled, brier_score_partial_loss

y_true = test_Ycat.values
y_prob = rf.predict_proba(test_std)

y_pred=np.array([1 if x >= 0.0 else 0 for x in y_prob[:,1]])

# %%
import collections
data = {'labeled_acc' : labeled_metric(y_true, y_pred, accuracy_score),
        'labeled_prec' : labeled_metric(y_true, y_pred, precision_score),
        'labeled_recall' : labeled_metric(y_true, y_pred, recall_score),
        'labeled_f1' : labeled_metric(y_true, y_pred, f1_score),
        'labeled_roc_auc' : labeled_metric(y_true, y_pred, roc_auc_score),
        'labeled_avg_prec' : labeled_metric(y_true, y_pred, average_precision_score),
        'labeled_brier' : labeled_metric(y_true, y_prob, brier_score_loss),
        'labeled_brier_pos' : labeled_metric(y_true, y_prob, brier_score_partial_loss, label=1),
        'labeled_brier_neg' : labeled_metric(y_true, y_prob, brier_score_partial_loss, label=0),
        'confusion_matrix_lab' : labeled_metric(y_true, y_pred, confusion_matrix),
        'pr_one_unlabeled' : pr_one_unlabeled(y_true, y_pred),
        'assumed_brier' : assumed_metric(y_true, y_prob, brier_score_loss),
        'assumed_brier_neg' : assumed_metric(y_true, y_prob, brier_score_partial_loss, label=0),
        'assumed_f1' : assumed_metric(y_true, y_pred, f1_score),
        'assumed_f1beta10' : assumed_metric(y_true, y_pred, fbeta_score, beta=10),
        'confusion_matrix_un' : assumed_metric(y_true, y_pred, confusion_matrix),
        'pu_score' : pu_score(y_true, y_pred),
        }
data_s = collections.OrderedDict(sorted(data.items()))
for k, v in data_s.items():
    print(k, ': ', v)
# Out:
# assumed_brier :  0.0054550714772
# assumed_brier_neg :  0.00212307060943
# assumed_f1 :  0.00944014092459
# assumed_f1beta10 :  0.324903801755
# confusion_matrix_lab :  [[  0 216]
#  [  0 418]]
# confusion_matrix_un :  [[    0 87722]
#  [    0   418]]
# labeled_acc :  0.659305993691
# labeled_avg_prec :  0.829652996845
# labeled_brier :  0.468722397476
# labeled_brier_neg :  0.012037037037
# labeled_brier_pos :  0.70471291866
# labeled_f1 :  0.794676806084
# labeled_prec :  0.659305993691
# labeled_recall :  1.0
# labeled_roc_auc :  0.5
# pr_one_unlabeled :  1.0
# pu_score :  1.0

# %% [markdown]
# # Optimize Hyper-parameters by Recall

# %%
rf=RandomForestClassifier(n_estimators=100)

# %%
#search 50 times     
seed = np.random.seed(1234)
n_iter_search = 20
random_search = RandomizedSearchCV(rf, param_distributions=param_dist,
                                   n_iter=n_iter_search,scoring ='recall',verbose=100)

start = time()
random_search.fit(X_res,y_res )
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time() - start), n_iter_search))

report(random_search.cv_results_)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] max_features=13, max_depth=3, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=10
# [CV]  max_features=13, max_depth=3, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=10, score=0.734279, total=  48.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   49.9s remaining:    0.0s
# [CV] max_features=13, max_depth=3, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=10
# [CV]  max_features=13, max_depth=3, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=10, score=0.780908, total=  57.8s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.8min remaining:    0.0s
# [CV] max_features=13, max_depth=3, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=10
# [CV]  max_features=13, max_depth=3, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=10, score=0.807242, total= 1.3min
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  3.1min remaining:    0.0s
# [CV] max_features=17, max_depth=3, min_samples_leaf=6, criterion=entropy, bootstrap=False, min_samples_split=4
# [CV]  max_features=17, max_depth=3, min_samples_leaf=6, criterion=entropy, bootstrap=False, min_samples_split=4, score=0.818493, total= 1.7min
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  4.9min remaining:    0.0s
# [CV] max_features=17, max_depth=3, min_samples_leaf=6, criterion=entropy, bootstrap=False, min_samples_split=4
# [CV]  max_features=17, max_depth=3, min_samples_leaf=6, criterion=entropy, bootstrap=False, min_samples_split=4, score=0.896418, total= 1.7min
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  6.6min remaining:    0.0s
# [CV] max_features=17, max_depth=3, min_samples_leaf=6, criterion=entropy, bootstrap=False, min_samples_split=4
# [CV]  max_features=17, max_depth=3, min_samples_leaf=6, criterion=entropy, bootstrap=False, min_samples_split=4, score=0.838919, total= 1.7min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  8.4min remaining:    0.0s
# [CV] max_features=2, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=3
# [CV]  max_features=2, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=3, score=0.154918, total=  17.6s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  8.7min remaining:    0.0s
# [CV] max_features=2, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=3
# [CV]  max_features=2, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=3, score=0.146247, total=  17.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  9.0min remaining:    0.0s
# [CV] max_features=2, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=3
# [CV]  max_features=2, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=3, score=0.044759, total=  17.3s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  9.4min remaining:    0.0s
# [CV] max_features=19, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=False, min_samples_split=5
# [CV]  max_features=19, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=False, min_samples_split=5, score=0.949814, total= 5.9min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 15.3min remaining:    0.0s
# [CV] max_features=19, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=False, min_samples_split=5
# [CV]  max_features=19, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=False, min_samples_split=5, score=0.998632, total= 6.3min
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 21.7min remaining:    0.0s
# [CV] max_features=19, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=False, min_samples_split=5
# [CV]  max_features=19, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=False, min_samples_split=5, score=0.998119, total= 6.4min
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 28.2min remaining:    0.0s
# [CV] max_features=16, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=6
# [CV]  max_features=16, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=6, score=0.829009, total= 1.1min
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 29.3min remaining:    0.0s
# [CV] max_features=16, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=6
# [CV]  max_features=16, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=6, score=0.841484, total= 1.1min
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 30.4min remaining:    0.0s
# [CV] max_features=16, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=6
# [CV]  max_features=16, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=6, score=0.874444, total= 1.0min
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 31.5min remaining:    0.0s
# [CV] max_features=5, max_depth=None, min_samples_leaf=4, criterion=gini, bootstrap=True, min_samples_split=4
# [CV]  max_features=5, max_depth=None, min_samples_leaf=4, criterion=gini, bootstrap=True, min_samples_split=4, score=0.955841, total= 1.4min
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 33.0min remaining:    0.0s
# [CV] max_features=5, max_depth=None, min_samples_leaf=4, criterion=gini, bootstrap=True, min_samples_split=4
# [CV]  max_features=5, max_depth=None, min_samples_leaf=4, criterion=gini, bootstrap=True, min_samples_split=4, score=0.996281, total= 1.5min
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 34.5min remaining:    0.0s
# [CV] max_features=5, max_depth=None, min_samples_leaf=4, criterion=gini, bootstrap=True, min_samples_split=4
# [CV]  max_features=5, max_depth=None, min_samples_leaf=4, criterion=gini, bootstrap=True, min_samples_split=4, score=0.996110, total= 1.4min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 36.0min remaining:    0.0s
# [CV] max_features=7, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=7
# [CV]  max_features=7, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=7, score=0.556833, total=  40.6s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 36.7min remaining:    0.0s
# [CV] max_features=7, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=7
# [CV]  max_features=7, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=7, score=0.600846, total=  41.7s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 37.5min remaining:    0.0s
# [CV] max_features=7, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=7
# [CV]  max_features=7, max_depth=3, min_samples_leaf=10, criterion=gini, bootstrap=False, min_samples_split=7, score=0.590245, total=  39.7s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed: 38.2min remaining:    0.0s
# [CV] max_features=10, max_depth=None, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=8
# [CV]  max_features=10, max_depth=None, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=8, score=0.953619, total= 3.3min
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed: 41.6min remaining:    0.0s
# [CV] max_features=10, max_depth=None, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=8
# [CV]  max_features=10, max_depth=None, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=8, score=0.998675, total= 3.6min
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed: 45.3min remaining:    0.0s
# [CV] max_features=10, max_depth=None, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=8
# [CV]  max_features=10, max_depth=None, min_samples_leaf=5, criterion=entropy, bootstrap=False, min_samples_split=8, score=0.998632, total= 3.6min
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed: 49.0min remaining:    0.0s
# [CV] max_features=5, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=8
# [CV]  max_features=5, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=8, score=0.474458, total=  35.6s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed: 49.6min remaining:    0.0s
# [CV] max_features=5, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=8
# [CV]  max_features=5, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=8, score=0.552710, total=  36.2s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed: 50.3min remaining:    0.0s
# [CV] max_features=5, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=8
# [CV]  max_features=5, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=8, score=0.431045, total=  35.6s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 50.9min remaining:    0.0s
# [CV] max_features=8, max_depth=None, min_samples_leaf=5, criterion=gini, bootstrap=False, min_samples_split=10
# [CV]  max_features=8, max_depth=None, min_samples_leaf=5, criterion=gini, bootstrap=False, min_samples_split=10, score=0.955457, total= 2.7min
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed: 53.7min remaining:    0.0s
# [CV] max_features=8, max_depth=None, min_samples_leaf=5, criterion=gini, bootstrap=False, min_samples_split=10
# [CV]  max_features=8, max_depth=None, min_samples_leaf=5, criterion=gini, bootstrap=False, min_samples_split=10, score=0.997478, total= 3.0min
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed: 56.8min remaining:    0.0s
# [CV] max_features=8, max_depth=None, min_samples_leaf=5, criterion=gini, bootstrap=False, min_samples_split=10
# [CV]  max_features=8, max_depth=None, min_samples_leaf=5, criterion=gini, bootstrap=False, min_samples_split=10, score=0.998034, total= 3.0min
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed: 59.8min remaining:    0.0s
# [CV] max_features=14, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=4
# [CV]  max_features=14, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=4, score=0.719745, total= 1.1min
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed: 60.9min remaining:    0.0s
# [CV] max_features=14, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=4
# [CV]  max_features=14, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=4, score=0.842767, total= 1.0min
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed: 62.0min remaining:    0.0s
# [CV] max_features=14, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=4
# [CV]  max_features=14, max_depth=3, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=4, score=0.815492, total= 1.0min
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed: 63.1min remaining:    0.0s
# [CV] max_features=19, max_depth=3, min_samples_leaf=1, criterion=gini, bootstrap=True, min_samples_split=2
# [CV]  max_features=19, max_depth=3, min_samples_leaf=1, criterion=gini, bootstrap=True, min_samples_split=2, score=0.831659, total= 1.1min
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed: 64.2min remaining:    0.0s
# [CV] max_features=19, max_depth=3, min_samples_leaf=1, criterion=gini, bootstrap=True, min_samples_split=2
# [CV]  max_features=19, max_depth=3, min_samples_leaf=1, criterion=gini, bootstrap=True, min_samples_split=2, score=0.860722, total=  52.3s
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed: 65.1min remaining:    0.0s
# [CV] max_features=19, max_depth=3, min_samples_leaf=1, criterion=gini, bootstrap=True, min_samples_split=2
# [CV]  max_features=19, max_depth=3, min_samples_leaf=1, criterion=gini, bootstrap=True, min_samples_split=2, score=0.891117, total=  46.6s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed: 65.9min remaining:    0.0s
# [CV] max_features=14, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=True, min_samples_split=9
# [CV]  max_features=14, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=True, min_samples_split=9, score=0.952806, total= 2.5min
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed: 68.5min remaining:    0.0s
# [CV] max_features=14, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=True, min_samples_split=9
# [CV]  max_features=14, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=True, min_samples_split=9, score=0.996794, total= 3.0min
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed: 71.6min remaining:    0.0s
# [CV] max_features=14, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=True, min_samples_split=9
# [CV]  max_features=14, max_depth=None, min_samples_leaf=7, criterion=entropy, bootstrap=True, min_samples_split=9, score=0.996366, total= 2.2min
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed: 73.8min remaining:    0.0s
# [CV] max_features=14, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=2
# [CV]  max_features=14, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=2, score=0.950840, total= 2.7min
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed: 76.6min remaining:    0.0s
# [CV] max_features=14, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=2
# [CV]  max_features=14, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=2, score=0.999231, total= 3.1min
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed: 79.7min remaining:    0.0s
# [CV] max_features=14, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=2
# [CV]  max_features=14, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=False, min_samples_split=2, score=0.999487, total= 8.8min
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed: 88.6min remaining:    0.0s
# [CV] max_features=15, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=7
# [CV]  max_features=15, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=7, score=0.783696, total= 1.3min
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed: 90.0min remaining:    0.0s
# [CV] max_features=15, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=7
# [CV]  max_features=15, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=7, score=0.789415, total= 1.3min
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed: 91.3min remaining:    0.0s
# [CV] max_features=15, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=7
# [CV]  max_features=15, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=True, min_samples_split=7, score=0.818699, total= 1.3min
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 92.7min remaining:    0.0s
# [CV] max_features=12, max_depth=None, min_samples_leaf=2, criterion=entropy, bootstrap=False, min_samples_split=10
# [CV]  max_features=12, max_depth=None, min_samples_leaf=2, criterion=entropy, bootstrap=False, min_samples_split=10, score=0.951139, total= 4.3min
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed: 97.0min remaining:    0.0s
# [CV] max_features=12, max_depth=None, min_samples_leaf=2, criterion=entropy, bootstrap=False, min_samples_split=10
# [CV]  max_features=12, max_depth=None, min_samples_leaf=2, criterion=entropy, bootstrap=False, min_samples_split=10, score=0.998931, total= 3.5min
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed: 100.6min remaining:    0.0s
# [CV] max_features=12, max_depth=None, min_samples_leaf=2, criterion=entropy, bootstrap=False, min_samples_split=10
# [CV]  max_features=12, max_depth=None, min_samples_leaf=2, criterion=entropy, bootstrap=False, min_samples_split=10, score=0.999273, total= 4.8min
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed: 105.5min remaining:    0.0s
# [CV] max_features=18, max_depth=3, min_samples_leaf=2, criterion=gini, bootstrap=True, min_samples_split=2
# [CV]  max_features=18, max_depth=3, min_samples_leaf=2, criterion=gini, bootstrap=True, min_samples_split=2, score=0.852520, total= 1.7min
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed: 107.3min remaining:    0.0s
# [CV] max_features=18, max_depth=3, min_samples_leaf=2, criterion=gini, bootstrap=True, min_samples_split=2
# [CV]  max_features=18, max_depth=3, min_samples_leaf=2, criterion=gini, bootstrap=True, min_samples_split=2, score=0.881199, total= 1.7min
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed: 109.0min remaining:    0.0s
# [CV] max_features=18, max_depth=3, min_samples_leaf=2, criterion=gini, bootstrap=True, min_samples_split=2
# [CV]  max_features=18, max_depth=3, min_samples_leaf=2, criterion=gini, bootstrap=True, min_samples_split=2, score=0.862945, total= 1.8min
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed: 110.9min remaining:    0.0s
# [CV] max_features=13, max_depth=3, min_samples_leaf=8, criterion=gini, bootstrap=False, min_samples_split=9
# [CV]  max_features=13, max_depth=3, min_samples_leaf=8, criterion=gini, bootstrap=False, min_samples_split=9, score=0.756209, total= 1.5min
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed: 112.4min remaining:    0.0s
# [CV] max_features=13, max_depth=3, min_samples_leaf=8, criterion=gini, bootstrap=False, min_samples_split=9
# [CV]  max_features=13, max_depth=3, min_samples_leaf=8, criterion=gini, bootstrap=False, min_samples_split=9, score=0.747606, total= 1.5min
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed: 114.0min remaining:    0.0s
# [CV] max_features=13, max_depth=3, min_samples_leaf=8, criterion=gini, bootstrap=False, min_samples_split=9
# [CV]  max_features=13, max_depth=3, min_samples_leaf=8, criterion=gini, bootstrap=False, min_samples_split=9, score=0.774667, total= 1.5min
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed: 115.5min remaining:    0.0s
# [CV] max_features=6, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=False, min_samples_split=2
# [CV]  max_features=6, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=False, min_samples_split=2, score=0.487325, total=  47.0s
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed: 116.3min remaining:    0.0s
# [CV] max_features=6, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=False, min_samples_split=2
# [CV]  max_features=6, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=False, min_samples_split=2, score=0.569767, total=  47.9s
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed: 117.1min remaining:    0.0s
# [CV] max_features=6, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=False, min_samples_split=2
# [CV]  max_features=6, max_depth=3, min_samples_leaf=7, criterion=gini, bootstrap=False, min_samples_split=2, score=0.555233, total=  48.0s
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed: 118.0min remaining:    0.0s
# [CV] max_features=7, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=3
# [CV]  max_features=7, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=3, score=0.956654, total= 2.6min
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed: 120.7min remaining:    0.0s
# [CV] max_features=7, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=3
# [CV]  max_features=7, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=3, score=0.998632, total= 2.7min
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed: 123.4min remaining:    0.0s
# [CV] max_features=7, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=3
# [CV]  max_features=7, max_depth=None, min_samples_leaf=1, criterion=entropy, bootstrap=True, min_samples_split=3, score=0.998846, total= 2.7min
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed: 126.3min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed: 126.3min finished
# RandomizedSearchCV took 7874.27 seconds for 20 candidates parameter settings.
# Model with rank: 1
# Mean validation score: 0.985 (std: 0.020)
# Parameters: {'max_features': 7, 'max_depth': None, 'min_samples_leaf': 1, 'criterion': 'entropy', 'bootstrap': True, 'min_samples_split': 3}
#
# Model with rank: 2
# Mean validation score: 0.984 (std: 0.020)
# Parameters: {'max_features': 8, 'max_depth': None, 'min_samples_leaf': 5, 'criterion': 'gini', 'bootstrap': False, 'min_samples_split': 10}
#
# Model with rank: 3
# Mean validation score: 0.984 (std: 0.021)
# Parameters: {'max_features': 10, 'max_depth': None, 'min_samples_leaf': 5, 'criterion': 'entropy', 'bootstrap': False, 'min_samples_split': 8}

# %%
#RandomizedSearchCV took 7874.27 seconds for 20 candidates parameter settings.
#Model with rank: 1
#Mean validation score: 0.985 (std: 0.020)
#Parameters: {'max_features': 7, 'max_depth': None, 'min_samples_leaf': 1, 'criterion': 'entropy', 
#'bootstrap': True, 'min_samples_split': 3}

rf=RandomForestClassifier(n_estimators=500)
rf=RandomForestClassifier(criterion='entropy', max_depth=None, min_samples_split=3, 
                       min_samples_leaf=1,max_features=7,bootstrap=True,random_state=1234)

# %%
#fit the model
rf.fit(X_res,y_res)

predicted_probs = rf.predict_proba(train_std)
a= predicted_probs[:,1]
np.mean(a)
b= predicted_probs[:,0]
np.mean(b)
a1=sorted(a,reverse=True)
a2=pd.DataFrame(a1)
a2.iloc[train_PERT.value_counts()["Y"]*4-1,:]
# Out:
# 0    0.1
# Name: 6679, dtype: float64

# %%
#Synchronize with Jeff's Scoring Functions
from sklearn.metrics import accuracy_score, precision_score, recall_score, \
    f1_score, roc_auc_score, average_precision_score, brier_score_loss, \
    fbeta_score, confusion_matrix
from creonmetrics import labeled_metric, assumed_metric, pu_score, \
    pr_one_unlabeled, brier_score_partial_loss

y_true = test_Ycat.values
y_prob = rf.predict_proba(test_std)

y_pred=np.array([1 if x >= 0.1 else 0 for x in y_prob[:,1]])

# %%
import collections
data = {'labeled_acc' : labeled_metric(y_true, y_pred, accuracy_score),
        'labeled_prec' : labeled_metric(y_true, y_pred, precision_score),
        'labeled_recall' : labeled_metric(y_true, y_pred, recall_score),
        'labeled_f1' : labeled_metric(y_true, y_pred, f1_score),
        'labeled_roc_auc' : labeled_metric(y_true, y_pred, roc_auc_score),
        'labeled_avg_prec' : labeled_metric(y_true, y_pred, average_precision_score),
        'labeled_brier' : labeled_metric(y_true, y_prob, brier_score_loss),
        'labeled_brier_pos' : labeled_metric(y_true, y_prob, brier_score_partial_loss, label=1),
        'labeled_brier_neg' : labeled_metric(y_true, y_prob, brier_score_partial_loss, label=0),
        'confusion_matrix_lab' : labeled_metric(y_true, y_pred, confusion_matrix),
        'pr_one_unlabeled' : pr_one_unlabeled(y_true, y_pred),
        'assumed_brier' : assumed_metric(y_true, y_prob, brier_score_loss),
        'assumed_brier_neg' : assumed_metric(y_true, y_prob, brier_score_partial_loss, label=0),
        'assumed_f1' : assumed_metric(y_true, y_pred, f1_score),
        'assumed_f1beta10' : assumed_metric(y_true, y_pred, fbeta_score, beta=10),
        'confusion_matrix_un' : assumed_metric(y_true, y_pred, confusion_matrix),
        'pu_score' : pu_score(y_true, y_pred),
        }
data_s = collections.OrderedDict(sorted(data.items()))
for k, v in data_s.items():
    print(k, ': ', v)
# Out:
# assumed_brier :  0.00613907466821
# assumed_brier_neg :  0.00309353034625
# assumed_f1 :  0.100098135427
# assumed_f1beta10 :  0.650707427994
# confusion_matrix_lab :  [[161  55]
#  [112 306]]
# confusion_matrix_un :  [[82332  5390]
#  [  112   306]]
# labeled_acc :  0.736593059937
# labeled_avg_prec :  0.878179498525
# labeled_brier :  0.431848400806
# labeled_brier_neg :  0.01881719393
# labeled_brier_pos :  0.64528079479
# labeled_f1 :  0.785622593068
# labeled_prec :  0.847645429363
# labeled_recall :  0.732057416268
# labeled_roc_auc :  0.738713893319
# pr_one_unlabeled :  0.0609672479601
# pu_score :  8.29265036363
