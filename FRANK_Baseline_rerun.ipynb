# %%
import pandas as pd
import numpy as np
from scipy.stats import randint as sp_randint
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from sklearn.metrics import brier_score_loss
from sklearn.model_selection import RandomizedSearchCV
from time import time

# %%
#read table: train as total training dataset, train_re as resampled training
#dataset for modeling,test as test dataset

train=pd.read_table('training.txt')  #80% of original data randomly selected on SAS
test=pd.read_table('testing.txt')  #Left 20%
#Unlabeled data was resampled on SAS to be 
#Count of Resampled Unlabeled + Count of Labeled Negative = Count of Labeled Positive * 4
train_re=pd.read_table('training_re.txt')

# %%
#extract response column
target = train_re.iloc[:,[293]]

#extract train matrix
tr = train_re.iloc[:,1:293]

#extract test matrix
tt = test.iloc[:,2:294]

#extract response variable for model, strange data type for python 
target=target['PERT_Y']

# %%
#set random forest tree as 500
rf=RandomForestClassifier(n_estimators=500)
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
#hyper parameter options, could also apply to other model. 
param_dist = {"max_depth": [3, None],
              "max_features": sp_randint(1, 20),
              "min_samples_split": sp_randint(2, 11),
              "min_samples_leaf": sp_randint(1, 11),
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

# %%
#search 50 times  
seed = np.random.seed(1234)
n_iter_search = 50
random_search = RandomizedSearchCV(rf, param_distributions=param_dist,
                                   n_iter=n_iter_search, n_jobs=-1, verbose=100)

start = time()
random_search.fit(tr,target )
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time() - start), n_iter_search))

report(random_search.cv_results_)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to new file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    9.7s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   11.3s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   12.7s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   18.9s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   19.2s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:   25.4s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:   28.3s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   28.6s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:   29.8s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   30.7s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:   31.2s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   31.6s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   38.4s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:   43.0s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:   47.2s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   57.5s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   59.1s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:   59.9s
# Pickling array (shape=(292,), dtype=object).
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:   59.9s
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  1.0min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  1.1min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  1.1min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  1.1min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  1.1min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  1.1min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  1.2min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  1.2min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  1.2min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  1.2min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  1.2min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  1.2min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  1.2min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  1.3min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.4min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  1.4min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  1.5min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  1.5min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  1.5min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:  1.5min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  1.5min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:  1.6min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.6min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:  1.8min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  1.8min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  1.9min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  1.9min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:  1.9min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:  1.9min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:  2.0min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:  2.0min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:  2.0min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:  2.0min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  2.0min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:  2.0min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:  2.0min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:  2.1min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:  2.1min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:  2.1min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:  2.1min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:  2.1min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:  2.1min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:  2.1min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:  2.2min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  2.2min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:  2.2min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed:  2.2min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed:  2.2min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:  2.3min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed:  2.3min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed:  2.3min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed:  2.3min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed:  2.3min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:  2.3min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed:  2.3min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed:  2.3min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed:  2.3min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed:  2.4min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed:  2.4min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed:  2.4min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:  2.4min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed:  2.4min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed:  2.4min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed:  2.4min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed:  2.4min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed:  2.5min
# Pickling array (shape=(292,), dtype=object).
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed:  2.5min
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed:  2.5min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:  2.5min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed:  2.5min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed:  2.5min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed:  2.6min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed:  2.7min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed:  2.7min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed:  2.8min
# Pickling array (shape=(292,), dtype=object).
# ...
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed:  3.3min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:  3.3min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:  3.3min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:  3.3min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed:  3.3min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed:  3.4min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed:  3.4min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:  3.4min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed:  3.4min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  3.4min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed:  3.5min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:  3.5min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed:  3.6min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:  3.6min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed:  3.7min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed:  3.7min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed:  3.7min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed:  3.7min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed:  3.7min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed:  3.8min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed:  3.8min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed:  3.8min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed:  3.9min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed:  3.9min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed:  3.9min
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 137 out of 150 | elapsed:  3.9min remaining:   22.4s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 139 out of 150 | elapsed:  4.0min remaining:   18.9s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5566,), dtype=int32).
# Pickling array (shape=(2784,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 141 out of 150 | elapsed:  4.0min remaining:   15.4s
# Pickling array (shape=(292,), dtype=object).
# Memmaping (shape=(292, 8350), dtype=int64) to old file C:\Users\motoharu.dei\AppData\Local\Temp\joblib_memmaping_pool_6884_190537176\6884-107636216-4feb91f2aaa8da14794982997381cecb.pkl
# Pickling array (shape=(292,), dtype=object).
# Pickling array (shape=(8350,), dtype=object).
# Pickling array (shape=(5568,), dtype=int32).
# Pickling array (shape=(2782,), dtype=int32).
# [Parallel(n_jobs=-1)]: Done 143 out of 150 | elapsed:  4.1min remaining:   11.8s
# [Parallel(n_jobs=-1)]: Done 145 out of 150 | elapsed:  4.1min remaining:    8.4s
# [Parallel(n_jobs=-1)]: Done 147 out of 150 | elapsed:  4.1min remaining:    4.9s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:  4.2min finished
# RandomizedSearchCV took 305.50 seconds for 50 candidates parameter settings.
# Model with rank: 1
# Mean validation score: 0.902 (std: 0.014)
# Parameters: {'max_depth': None, 'min_samples_leaf': 5, 'max_features': 18, 'criterion': 'gini', 'bootstrap': False, 'min_samples_split': 9}
#
# Model with rank: 2
# Mean validation score: 0.901 (std: 0.012)
# Parameters: {'max_depth': None, 'min_samples_leaf': 6, 'max_features': 19, 'criterion': 'entropy', 'bootstrap': False, 'min_samples_split': 4}
#
# Model with rank: 3
# Mean validation score: 0.899 (std: 0.012)
# Parameters: {'min_samples_leaf': 10, 'max_depth': None, 'max_features': 19, 'criterion': 'gini', 'bootstrap': False, 'min_samples_split': 3}

# %%
#RandomizedSearchCV took 305.50 seconds for 50 candidates parameter settings.
#Model with rank: 1
#Mean validation score: 0.902 (std: 0.014)
#Parameters: {'max_depth': None, 'min_samples_leaf': 5, 'max_features': 18, 
#'criterion': 'gini', 'bootstrap': False, 'min_samples_split': 9}

#build random forest model after random search.
rf=RandomForestClassifier(criterion='gini', max_depth=None, min_samples_split=9, 
                       min_samples_leaf=5,max_features=18,bootstrap=False,random_state=1234)

#fit the model
rf.fit(tr, target)

#apply to original train data from resample train data model result
tr1 = train.iloc[:,1:293]
predicted_probs1 = rf.predict_proba(tr1)
a= predicted_probs1[:,1]
np.mean(a)
b= predicted_probs1[:,0]
np.mean(b)
a1=sorted(a, reverse=True)
a2=pd.DataFrame(a1)

#get cut-off probability at labeling 4-fold positive to original positive (1670*4=6680)
cr=a2.iloc[target.value_counts()["Y"]*4-1,:]
print(cr)
# Out:
# 0    0.620635
# Name: 6679, dtype: float64

# %%
#Synchronize with Jeff's Scoring Functions
from sklearn.metrics import accuracy_score, precision_score, recall_score, \
    f1_score, roc_auc_score, average_precision_score, brier_score_loss, \
    fbeta_score, confusion_matrix
from creonmetrics import labeled_metric, assumed_metric, pu_score, \
    pr_one_unlabeled, brier_score_partial_loss

y_true = np.transpose(test.iloc[:,0].values)
y_prob = rf.predict_proba(tt)

y_pred=np.array([1 if x >= 0.620635 else 0 for x in y_prob[:,1]])

# %%
import collections
data = {'labeled_acc' : labeled_metric(y_true, y_pred, accuracy_score),
        'labeled_prec' : labeled_metric(y_true, y_pred, precision_score),
        'labeled_recall' : labeled_metric(y_true, y_pred, recall_score),
        'labeled_f1' : labeled_metric(y_true, y_pred, f1_score),
        'labeled_roc_auc' : labeled_metric(y_true, y_pred, roc_auc_score),
        'labeled_avg_prec' : labeled_metric(y_true, y_pred, average_precision_score),
        'labeled_brier' : labeled_metric(y_true, y_prob, brier_score_loss),
        'labeled_brier_pos' : labeled_metric(y_true, y_prob, brier_score_partial_loss, label=1),
        'labeled_brier_neg' : labeled_metric(y_true, y_prob, brier_score_partial_loss, label=0),
        'confusion_matrix_lab' : labeled_metric(y_true, y_pred, confusion_matrix),
        'pr_one_unlabeled' : pr_one_unlabeled(y_true, y_pred),
        'assumed_brier' : assumed_metric(y_true, y_prob, brier_score_loss),
        'assumed_brier_neg' : assumed_metric(y_true, y_prob, brier_score_partial_loss, label=0),
        'assumed_f1' : assumed_metric(y_true, y_pred, f1_score),
        'assumed_f1beta10' : assumed_metric(y_true, y_pred, fbeta_score, beta=10),
        'confusion_matrix_un' : assumed_metric(y_true, y_pred, confusion_matrix),
        'pu_score' : pu_score(y_true, y_pred),
        }
data_s = collections.OrderedDict(sorted(data.items()))
for k, v in data_s.items():
    print(k, ': ', v)
# Out:
# assumed_brier :  0.0331460952462
# assumed_brier_neg :  0.0320835681346
# assumed_f1 :  0.187751004016
# assumed_f1beta10 :  0.435445197584
# confusion_matrix_lab :  [[210   6]
#  [231 187]]
# confusion_matrix_un :  [[86335  1387]
#  [  231   187]]
# labeled_acc :  0.6261829653
# labeled_avg_prec :  0.890316825227
# labeled_brier :  0.184715372179
# labeled_brier_neg :  0.0465160873385
# labeled_brier_pos :  0.25612935669
# labeled_f1 :  0.612111292962
# labeled_prec :  0.968911917098
# labeled_recall :  0.447368421053
# labeled_roc_auc :  0.709795321637
# pr_one_unlabeled :  0.015781774964
# pu_score :  11.2072476215

# %%
rfimp=pd.DataFrame(rf.feature_importances_, index=tt.columns).sort_values(by=0, ascending=False)
rfimp.head(50)
# Out:
#                            0
# DIAG_FLAG4_Sum      0.257138
# DIAG_FLAG5_Sum      0.144012
# DIAG_FLAG75_Sum     0.036151
# ndc_cat87_Sum       0.035965
# ndc_cat58_Sum       0.032024
# CPT_FLAG9_Sum       0.023963
# age                 0.016386
# CPT_FLAG44_Sum      0.013212
# DIAG_FLAG38_Sum     0.013183
# CPT_FLAG43_Sum      0.011318
# DIAG_FLAG48_Sum     0.010557
# CPT_FLAG48_Sum      0.008878
# DIAG_FLAG71_Sum     0.008842
# REVCODE_FLAG11_Sum  0.008581
# ndc_cat54_Sum       0.008469
# CPT_FLAG47_Sum      0.008340
# DIAG_FLAG54_Sum     0.008294
# ndc_cat16_Sum       0.008261
# CPT_FLAG49_Sum      0.008207
# DIAG_FLAG72_Sum     0.007977
# ndc_cat11_Sum       0.007954
# REVCODE_FLAG19_Sum  0.007574
# ndc_cat85_Sum       0.007090
# DIAG_FLAG9_Sum      0.006900
# DIAG_FLAG7_Sum      0.006874
# DIAG_FLAG24_Sum     0.006605
# DIAG_FLAG53_Sum     0.006598
# DIAG_FLAG42_Sum     0.006567
# DIAG_FLAG55_Sum     0.006301
# DIAG_FLAG45_Sum     0.006056
# ndc_cat20_Sum       0.005817
# DIAG_FLAG49_Sum     0.005793
# REVCODE_FLAG15_Sum  0.005339
# ndc_cat40_Sum       0.005272
# ndc_cat22_Sum       0.005168
# ndc_cat18_Sum       0.005114
# CPT_FLAG20_Sum      0.004990
# ndc_cat15_Sum       0.004980
# ndc_cat70_Sum       0.004743
# CPT_FLAG46_Sum      0.004612
# DIAG_FLAG77_Sum     0.004506
# ndc_cat21_Sum       0.004409
# REVCODE_FLAG38_Sum  0.004369
# ndc_cat44_Sum       0.004278
# DIAG_FLAG6_Sum      0.004115
# DIAG_FLAG60_Sum     0.004091
# DIAG_FLAG11_Sum     0.004048
# DIAG_FLAG3_Sum      0.004024
# DIAG_FLAG67_Sum     0.004019
# REVCODE_FLAG23_Sum  0.003851
